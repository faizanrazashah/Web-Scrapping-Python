# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
driver = webdriver.Chrome('/Users/kkc/Projects_Jupyter/chromedriver_win32/chromedriver')

# %%
driver.get('https://www.stubhub.com/atlanta-hawks-tickets/performer/6769/')
content = driver.page_source
soup = BeautifulSoup(content)

# %%
soup
# Out:
# <html lang="en-US"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,minimum-scale=1.0,maximum-scale=5.0" name="viewport"/>
# <title>Atlanta Hawks Tickets - StubHub</title>
# <meta content="Check out upcoming Hawks games and team schedules. Buy and sell your Atlanta Hawks tickets today at StubHub - 100% guaranteed by FanProtect." name="description"/><!-- Canonical and hreflang tags -->
# <link href="https://www.stubhub.com/atlanta-hawks-tickets/performer/6769/" rel="canonical"/>
# <link href="https://www.stubhub.ca/atlanta-hawks-tickets/performer/6769/" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.stubhub.ca/billets-atlanta-hawks/fr/performer/6769/" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.stubhub.com/atlanta-hawks-tickets/performer/6769/" hreflang="en-US" rel="alternate"/>
# <link href="https://www.stubhub.com/entradas-atlanta-hawks/es/performer/6769/" hreflang="es-US" rel="alternate"/>
# <!-- OG tags -->
# ...

# %%
date = []
for a in soup.find_all("span", attrs={'class':'DateStamp__MonthDateYear'}):
    date.append(a.text)

# %%
event_item = []
for a in soup.find_all("div", attrs={'class':'EventRedirection'}):
    event_item.append(a.text)

# %%
time = []
for a in soup.find_all("time"):
    time.append(a.text)

# %%
def get_odd_numbers(numbers):
    odd_numbers = []

    for number in numbers:
        if number % 2 == 1:
            odd_numbers.append(number)

    return odd_numbers

# %%
time_lst = []
for i in get_odd_numbers(df.index):
    i = time[i]
    time_lst.append(i)

# %%
df = pd.DataFrame({'Time': time_lst})
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
time_lst
# Out:
# ['7:00 PM',
#  '6:00 PM',
#  '7:30 PM',
#  '7:30 PM',
#  '7:30 PM',
#  '7:30 PM',
#  '7:30 PM',
#  '7:00 PM',
#  '7:30 PM',
#  '7:00 PM',
#  '7:30 PM',
#  '6:00 PM',
#  '7:00 PM',
#  '7:30 PM',
#  '7:30 PM',
#  '7:00 PM',
#  '7:30 PM',
#  '7:30 PM',
#  '7:30 PM',
#  '7:00 PM']

# %%
price = []
for a in soup.find_all("div", attrs={'class':'AdvisoryPriceDisplay__content'}):
    price.append(a.text)

# %%
price
# Out:
# ['$16',
#  '$41',
#  '$9',
#  '$20',
#  '$37',
#  '$16',
#  '$11',
#  '$11',
#  '$51',
#  '$11',
#  '$42',
#  '$24',
#  '$22',
#  '$77',
#  '$16',
#  '$20',
#  '$21',
#  '$22',
#  '$24',
#  '$28']

# %%
data = pd.DataFrame({'Date': date, 'Event Item': event_item, 'Time': time_lst, 'Price': price})

# %%
data
# Out:
#             Date                               Event Item     Time Price
# 0   Nov 12, 2021          Atlanta Hawks at Denver Nuggets  7:00 PM   $16
# 1   Nov 14, 2021         Milwaukee Bucks at Atlanta Hawks  6:00 PM   $41
# 2   Nov 15, 2021           Orlando Magic at Atlanta Hawks  7:30 PM    $9
# 3   Nov 17, 2021          Boston Celtics at Atlanta Hawks  7:30 PM   $20
# 4   Nov 20, 2021       Charlotte Hornets at Atlanta Hawks  7:30 PM   $37
# 5   Nov 22, 2021   Oklahoma City Thunder at Atlanta Hawks  7:30 PM   $16
# 6   Nov 24, 2021       Atlanta Hawks at San Antonio Spurs  7:30 PM   $11
# 7   Nov 26, 2021       Atlanta Hawks at Memphis Grizzlies  7:00 PM   $11
# 8   Nov 27, 2021         New York Knicks at Atlanta Hawks  7:30 PM   $51
# 9    Dec 1, 2021          Atlanta Hawks at Indiana Pacers  7:00 PM   $11
# 10   Dec 3, 2021      Philadelphia 76ers at Atlanta Hawks  7:30 PM   $42
# 11   Dec 5, 2021       Charlotte Hornets at Atlanta Hawks  6:00 PM   $24
# ...
